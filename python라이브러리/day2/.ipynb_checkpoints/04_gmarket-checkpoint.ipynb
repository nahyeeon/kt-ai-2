# %% [markdown]
# ### Gmarket
# - 베스트 상품 200개 데이터 수집
# - 상품의 이미지 200개 다운로드

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
# 1. URL 찾기

# %%
url = "http://corners.gmarket.co.kr/Bestsellers"

# %%
# 2. request > response : str(html)

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
# 3. bs > DataFrame

# %%
dom = BeautifulSoup(response.text, "html.parser")

# %%
# select items
elements = dom.select("#gBestWrap > div > div:nth-child(5) > div > ul > li")
len(elements)
# Out:
# 200

# %%
element = elements[0]

# %%
# select item data
data = {
    "title": element.select_one(".itemname").text,
    "link": element.select_one(".itemname").get("href"),
    "img": element.select_one("img").get("data-original"),
    "o_price": element.select_one(".o-price").text,
    "s_price": element.select_one(".s-price").text.strip().split("\n")[0],
}
data
# Out:
# {'title': '[비비고][비비고] (CJ제일제당)  차돌된장찌개 460G 5봉',
#  'link': 'http://item.gmarket.co.kr/Item?goodscode=2145403160&ver=637930882382082269',
#  'img': '//gdimg.gmarket.co.kr/2145403160/still/300?ver=2022071022',
#  'o_price': '',
#  's_price': '21,710원'}

# %%
# make DataFrame
datas = []
for element in elements:
    datas.append({
        "title": element.select_one(".itemname").text,
        "link": element.select_one(".itemname").get("href"),
        "img": "http:" + element.select_one("img.lazy").get("data-original"),
        "o_price": element.select_one(".o-price").text,
        "s_price": element.select_one(".s-price").text.strip().split("\n")[0],
    })
df = pd.DataFrame(datas)
df.tail(2)
# Out:
#                               title  \
# 198   [에프킬라](임박특가) 모기약 매트 무향 총 240매
# 199  [제주삼다수]제주삼다수 그린 2L 24병 /생수전문배송
#
#                                                   link  \
# 198  http://item.gmarket.co.kr/Item?goodscode=24477...
# 199  http://item.gmarket.co.kr/Item?goodscode=23168...
#
#                                                    img  o_price  s_price
# 198  http://gdimg.gmarket.co.kr/2447758655/still/30...           16,200원
# 199  http://gdimg.gmarket.co.kr/2316892877/still/30...  27,040원  23,520원

# %%
df.head()
# Out:
#                                                title  \
# 0                [비비고][비비고] (CJ제일제당)  차돌된장찌개 460G 5봉
# 1                   (깨비농원)제주 미니밤호박 보우짱 2kg(미니/7-10개)
# 2  제스프리 제스프리 썬골드키위 특대과 3.2kg(23~25과 개당 130g~140g내...
# 3                        청정우 차돌박이 (3초구이 샤브용) 250gX3팩
# 4                     12% 데이데이 여름/반팔/티셔츠/블라우스/원피스/니트
#
#                                                 link  \
# 0  http://item.gmarket.co.kr/Item?goodscode=21454...
# 1  http://item.gmarket.co.kr/Item?goodscode=18407...
# 2  http://item.gmarket.co.kr/Item?goodscode=24234...
# 3  http://item.gmarket.co.kr/Item?goodscode=15667...
# 4  http://item.gmarket.co.kr/Item?goodscode=15517...
#
#                                                  img  o_price  s_price
# 0  http://gdimg.gmarket.co.kr/2145403160/still/30...           21,710원
# 1  http://gdimg.gmarket.co.kr/1840750849/still/30...  21,800원  10,900원
# 2  http://gdimg.gmarket.co.kr/2423463596/still/30...  30,900원  27,740원
# 3  http://gdimg.gmarket.co.kr/1566708507/still/30...  29,900원  17,900원
# 4  http://gdimg.gmarket.co.kr/1551794470/still/30...  33,000원   9,900원

# %%
# 4. download image

# %%
# make directory
import os

if not os.path.exists("datas"):           
    os.makedirs("datas")

# %%
# %ls
# Out:
# 01_html.ipynb                       05_gmarket.ipynb
# 02_css_selector.ipynb               06_naver_article.ipynb
# 03_naver_relational_keywords.ipynb  __pycache__/
# 04_mois.ipynb                       datas/

# %%
img_link = df.loc[0, "img"]
print(img_link)
# Out:
# http://gdimg.gmarket.co.kr/2145403160/still/300?ver=2022071022

# %%
# download image

# %%
response = requests.get(img_link)
response
# Out:
# <Response [200]>

# %%
with open("datas/test.png", "wb") as file:
    file.write(response.content)

# %%
# %ls datas
# Out:
# 000.png   001.png   002.png   003.png   004.png   test.png

# %%
from PIL import Image as pil

# %%
pil.open("datas/test.png")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F90C0ACC0D0>

# %%
# 5개의 아이템 이미지 다운로드
for idx, data in df[:5].iterrows():
    filename = "0" * (3 - len(str(idx))) + str(idx)
    print(idx, end=" ")
    response = requests.get(data.img)
    with open(f"datas/{filename}.png", "wb") as file:
        file.write(response.content)
# Out:
# 0 1 2 3 4

# %%
# %ls datas
# Out:
# 000.png   001.png   002.png   003.png   004.png   test.png

# %%
pil.open("datas/002.png")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x300 at 0x7F90D29CFB80>
