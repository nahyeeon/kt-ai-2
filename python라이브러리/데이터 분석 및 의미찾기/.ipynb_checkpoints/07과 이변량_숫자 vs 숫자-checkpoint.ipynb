# %% [markdown]
# # 07과 이변량_숫자 vs 숫자

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.
# > ① 타이타닉 생존자
# ② 보스톤 시, 타운별 집값
# ③ 아이리스 꽃 분류
# ④ 뉴욕 공기 오염도

# %%
# 타이타닉 데이터
titanic = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/titanic.0.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 아이리스 꽃 분류
iris = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/iris.csv')
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 보스톤 집값 데이터
boston = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/boston.csv')
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# 뉴욕시 공기 오염도 데이터
air = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/air2.csv')
air['Date'] = pd.to_datetime(air['Date'])
air['Month'] = air.Date.dt.month
air['Weekday'] = air.Date.dt.weekday
air.head()
# Out:
#    Ozone  Solar.R  Wind  Temp       Date  Month  Weekday
# 0     41    190.0   7.4    67 1973-05-01      5        1
# 1     36    118.0   8.0    72 1973-05-02      5        2
# 2     12    149.0  12.6    74 1973-05-03      5        3
# 3     18    313.0  11.5    62 1973-05-04      5        4
# 4     19      NaN  14.3    56 1973-05-05      5        5

# %% [markdown]
# ## 2.시작하기

# %% [markdown]
# * 우리가 사용하는 도구는...
#     * 두 변수와의 관계를 살펴보기 위해, 두가지 도구(시각화, 수치화)를 이용합니다.
#     * 이 도구들도 각각 한계가 있습니다. 보이는게 전부가 아님을 꼭 명심하세요!
#     * 특히 수치화 도구(가설검정 도구)는 많은 가정들이 전제 됩니다.
#     * 그래서 이번 과정에서는 그 도구를 사용하는 데에 집중합니다.

# %% [markdown]
# ----

# %% [markdown]
# ## 2.시각화

# %% [markdown]
# * 상관 분석에 대해서 이야기 해봅시다.
#     * 상관 분석은 연속형 변수 X에 대한 연속형 변수 Y의 관계를 분석할 때 사용됩니다.
#     * Scatter를 통해 시각화 합니다.
# * 가설 : 온도(x)가 상승하면 아이스크림 판매량(y)을 증가할까?
#     * 어떤 관계가 보이나요?
#     * 얼마나 강한 관계인가요?
# * 숫자 vs 숫자를 비교할 때 중요한 관점이 **‘직선’ (Linearity)**입니다.

# %% [markdown]
# <img src='https://github.com/DA4BAM/image/blob/main/%EC%82%B0%EC%A0%90%EB%8F%84_ex.png?raw=true' width=500/>

# %% [markdown]
# ### 1) 산점도

# %% [markdown]
# * 문법
#     * plt.scatter( x축 값, y축 값 )
#     * plt.scatter( ‘x변수’, ‘y변수’, data = dataframe이름)

# %%
plt.scatter(air['Temp'], air['Ozone'])
plt.show()

# %%
plt.scatter('Temp', 'Ozone', data = air)
plt.xlabel('Temp')
plt.ylabel('Ozone')
plt.grid()
plt.show()

# %% [markdown]
# 그래프를 그렸으면, 그래프로부터 정보를 파악해야 합니다.
#
# 무엇이 보이나요?

# %%
# 온도 80 기준으로 퍼짐

# %% [markdown]
# #### 실습
# Temp, Wind, Solar.R 과 Ozone 과의 관계를 시각화 해 봅시다.

# %%
plt.figure(figsize=(15,6))

plt.subplot(1,3,1)
plt.scatter('Temp', 'Ozone', data=air)
plt.xlabel('Temp')
plt.ylabel('Ozone')

plt.subplot(1,3,2)
plt.scatter('Wind', 'Ozone', data=air)
plt.xlabel('Wind')
plt.ylabel('Ozone')

plt.subplot(1,3,3)
plt.scatter('Solar.R', 'Ozone', data=air)
plt.xlabel('Solar.R')
plt.ylabel('Ozone')

plt.tight_layout()
plt.show()

# %% [markdown]
# Ozone과 가장 강한 관계의 x변수는?

# %%
# Temp

# %% [markdown]
# * 두 변수의 관계
#     * 산점도에서 또렷한 패턴이 보인다면, 강한 관계로 볼 수 있습니다.
#     * 특히, 직선의 패턴이 보인다면

# %% [markdown]
# <img src='https://cqeacademy.com/wp-content/uploads/2018/06/Scatter-Plots-and-Correlation-Examples.png' width=800/>

# %% [markdown]
# ### 2) pairplot으로 한꺼번에 시각화 할 수 있습니다.
#
# * 숫자형 변수들에 대한 산점도를 한꺼번에 그려줍니다.
# * 그러나 **시간이 많이**걸립니다.

# %%
sns.pairplot(air)

# %% [markdown]
# ###  3) jointplot 로 살펴보기
#
# * jointplot은 산점도와 각각의 히스토그램을 함께 보여줍니다.

# %% [markdown]
# * Temp --> Ozone

# %%
sns.jointplot(x='Temp', y='Ozone', data = air)
plt.show()

# %% [markdown]
# * Wind --> Ozone

# %%
sns.jointplot(x='Wind', y='Ozone', data = air)
plt.show()

# %% [markdown]
# * Solar.R --> Ozone

# %%
sns.jointplot(x='Solar.R', y='Ozone', data = air)
plt.show()

# %% [markdown]
# 우리는 다양한 시각화를 통해서 결국은...

# %% [markdown]
# ## 3.수치화 : 상관분석

# %% [markdown]
# * 상관관계를 나타내는 두가지 숫자 : 공분산, 상관계수
#     * 둘 다 얼마나 직선으로 값들이 모여 있는지를 수치화

# %% [markdown]
# * 상관계수 𝑟
#     * 공분산을 표준화 한 값
#     * -1 ~ 1 사이의 값
#     * -1, 1에 가까울 수록 강한 상관관계를 나타냄.
#
# * 경험에 의한 대략의 기준(절대적인 기준이 절대 아닙니다.)
#     * 강한 : 0.5 < |𝑟| ≤ 1
#     * 중간 : 0.2 < |𝑟| ≤ 0.5
#     * 약한 : 0.1 < |𝑟| ≤ 0.2
#     * (거의)없음 : |𝑟| ≤ 0.1

# %%
import scipy.stats as spst

# %%
# 상관계수와 p-value 
spst.pearsonr(air['Temp'], air['Ozone'])  # x, y의 위치가 바껴도 상관 없음 !!!
# Out:
# (0.6833717861490114, 2.197769800200274e-22)

# %% [markdown]
# 결과는 튜플로 나오는데
#
# 1. 튜플의 첫 번째 값 : 상관계수를 뜻합니다.
# 2. 두번째 값 : p-value
#     * 귀무가설 : 상관 관계가 없다.(상관계수가 0이다.)
#     * 대립가설 : 상관 관계가 있다.(상관계수가 0이 아니다.)
# 3. 주의 사항 : 값에 NaN이 있으면 계산되지 않습니다. 반드시 .notnull()로 제외하고 수행해야 합니다.

# %%
# 데이터프레임으로 부터 수치형 데이터에 대한 상관계수 구하기
air.corr()
# Out:
#             Ozone   Solar.R      Wind      Temp     Month   Weekday
# Ozone    1.000000  0.280068 -0.605478  0.683372  0.174197 -0.012900
# Solar.R  0.280068  1.000000 -0.056792  0.275840 -0.075301  0.071189
# Wind    -0.605478 -0.056792  1.000000 -0.457988 -0.178293  0.037313
# Temp     0.683372  0.275840 -0.457988  1.000000  0.420947 -0.032574
# Month    0.174197 -0.075301 -0.178293  0.420947  1.000000  0.030261
# Weekday -0.012900  0.071189  0.037313 -0.032574  0.030261  1.000000

# %% [markdown]
# 위 결과로 부터,
# 1. 같은 변수끼리 구한 값 1은 의미 없다.
# 2. 상관계수의 절대값이
#     * 1에 가까울 수록 강한 상관관계
#     * 0에 가까울 수록 약한 상관관계
# 3. +는 양의 상관관계, -는 음의 상관관계

# %% [markdown]
# * 상관계수를 heatmap으로 시각화 할 수 있습니다.

# %%
plt.figure(figsize = (8, 8))
sns.heatmap(air.corr(), annot = True, fmt = '.3f', cmap = 'RdYlBu_r',  vmin = -1, vmax = 1)
plt.show()

# %% [markdown]
# 칼라를 변경하려면 아래 링크로 가서 color map 을 확인하고 조정하세요.
# cmap(color map) : https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %% [markdown]
# ### 실습 : 상관계수
# air 데이터를 이용합니다.

# %%
air.loc[air['Solar.R'].notnull()]   # 피어슨 상관관계에서는 null이 있으면 안됨.

# %%
# 상관계수를 구해봅시다.
# Temp --> Ozone
print(spst.pearsonr(air['Temp'],air['Ozone']))

# Wind --> Ozone
print(spst.pearsonr(air['Wind'],air['Ozone']))

# Solar.R --> Ozone
temp=air.loc[air['Solar.R'].notnull()]
print(spst.pearsonr(temp['Solar.R'],temp['Ozone']))
# Out:
# (0.6833717861490114, 2.197769800200274e-22)
# (-0.6054782354684075, 1.1255146087638192e-16)
# (0.2800681334905377, 0.0006175878788566531)

# %% [markdown]
# #### 차트로 보는 것과 상관계수로 비교하는 것에 차이가 있나요?
# * 상관계수 = 1,-1에 가까울수록 강한 상관관계를 가지고 p-value는 0.05보다 작으면 대립가설이 어느정도 성립한다.
# * 차트로 파악하기 어려울 경우 상관계수로 수치화하여 어느정도 상관이 있는지 확인할 수 있다.

# %% [markdown]
# ## 4.상관계수의 한계

# %% [markdown]
# * 상관계수에는 한계가 있습니다.
#
# <img src='https://upload.wikimedia.org/wikipedia/commons/thumb/d/d4/Correlation_examples2.svg/1920px-Correlation_examples2.svg.png' width=800/>

# %% [markdown]
# * Data Saurus

# %% [markdown]
# <img src='https://damassets.autodesk.net/content/dam/autodesk/research/publications-assets/gifs/same-stats-different-graphs/DinoSequentialSmaller.gif
# ' width=800/>

# %%
ds = pd.read_csv("https://raw.githubusercontent.com/DA4BAM/dataset/master/datasaurus.csv")

# %%
ds_names = ['dino','x_shape', 'star', 'circle', 'bullseye' ]

# %% [markdown]
# * 아래 5개 그룹의 수치화 결과(상관계수)를 보고 x와 y에 관계가 있는지 판단해 봅시다.

# %%
for i, d in enumerate(ds_names) :
    temp_ds = ds.loc[ds['dataset']==d]
    corr = spst.pearsonr(temp_ds['x'], temp_ds['y'])
    print(i)
    print('상관계수 : {:.4f},  P-value : {:.4f}'.format(corr[0], corr[1]))
    print('---------------------------------------')
# Out:
# 0
# 상관계수 : -0.0645,  P-value : 0.4459
# ---------------------------------------
# 1
# 상관계수 : -0.0656,  P-value : 0.4381
# ---------------------------------------
# 2
# 상관계수 : -0.0630,  P-value : 0.4566
# ---------------------------------------
# 3
# 상관계수 : -0.0683,  P-value : 0.4190
# ---------------------------------------
# 4
# 상관계수 : -0.0686,  P-value : 0.4173
# ---------------------------------------

# %%
# 5그룹 중 x와 y가 서로 관련이 있는 것은?

# 가장 관련이 있는것은?

# %% [markdown]
# * 그렇다면, 이제 그래프들을 관찰해 봅시다.
#     * 어떤 패턴이 있나요? 아니면 아무런 패턴도 없나요?
#     * 어떤 신호가 있나요? 아니면 노이즈만 있나요?

# %% [raw]
# enumerate(ds_names)

# %%
for i,d in enumerate(ds_names) :
    temp_ds = ds.loc[ds['dataset']==d]
    corr = spst.pearsonr(temp_ds['x'], temp_ds['y'])
    print(i, d)
    print('상관계수 : {:.4f},  P-value : {:.4f}'.format(corr[0], corr[1]))
    plt.scatter(temp_ds['x'], temp_ds['y'])
    plt.show()
# Out:
# 0 dino
# 상관계수 : -0.0645,  P-value : 0.4459
# 1 x_shape
# 상관계수 : -0.0656,  P-value : 0.4381
# 2 star
# 상관계수 : -0.0630,  P-value : 0.4566
# 3 circle
# 상관계수 : -0.0683,  P-value : 0.4190
# 4 bullseye
# 상관계수 : -0.0686,  P-value : 0.4173

# %% [markdown]
# * 이렇듯, 수치화해서 하나의 숫자로 요약하는 데에는 많은 장점이 있습니다. 그러나 한계도 분명히 있음을 알아야 합니다.

# %% [markdown]
# * 소수점 자릿수로 데이터의 모양이 완전히 바뀜

# %% [markdown]
# ----

# %% [markdown]
# # 종합실습

# %% [markdown]
# ## 1.환경준비

# %% [markdown]
# * 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * 데이터 불러오기 : 다음의 예제 데이터를 사용합니다.
# > ① 카시트 매출액
# ② 보스톤 시, 타운별 집값
# ③ 아이리스 꽃 분류
# ④ 뉴욕 공기 오염도

# %%
# 카시트 매출액
path = 'https://raw.githubusercontent.com/JunhoYu/Data-Analysis/main/Carseats.csv'
carseat = pd.read_csv(path)
carseat.drop('Education', axis = 1, inplace = True)
carseat.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %%
# 아이리스 꽃 분류
iris = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/iris.csv')
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 보스톤 집값 데이터
boston = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/boston2_NA.csv')
boston.head()
# Out:
#       crim  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv  zn2
# 0  396.90   4.98  24.0  1.0
# 1  396.90   9.14  21.6  0.0
# 2  392.83   4.03  34.7  0.0
# 3  394.63   2.94  33.4  0.0
# 4  396.90   5.33  36.2  0.0

# %%
# 뉴욕시 공기 오염도 데이터
air = pd.read_csv('https://raw.githubusercontent.com/DA4BAM/dataset/master/air2.csv')
air['Date'] = pd.to_datetime(air['Date'])
air['Month'] = air.Date.dt.month
air['Weekday'] = air.Date.dt.weekday
air.head()
# Out:
#    Ozone  Solar.R  Wind  Temp       Date  Month  Weekday
# 0     41    190.0   7.4    67 1973-05-01      5        1
# 1     36    118.0   8.0    72 1973-05-02      5        2
# 2     12    149.0  12.6    74 1973-05-03      5        3
# 3     18    313.0  11.5    62 1973-05-04      5        4
# 4     19      NaN  14.3    56 1973-05-05      5        5

# %% [markdown]
# ## 2.시각화

# %% [markdown]
# ### 1) 산점도 : plt.scatter, sns.scatterplot, sns.jointplot

# %% [markdown]
# ① iris의 Petal.Length와 Petal.Width의 관계를 살펴보기 위해 산점도를 그려봅시다.
# * plt.scatter

# %%
plt.scatter('Petal.Length', 'Petal.Width', data=iris)
plt.show()

# %% [markdown]
# * sns.scatterplot

# %%
sns.scatterplot(x='Petal.Length', y='Petal.Width', data=iris)
plt.show()

# %% [markdown]
# * sns.scatterplot(    , hue = 'Species')

# %%
sns.scatterplot(x= 'Petal.Length', y='Petal.Width', data=iris, hue = 'Species')
plt.show()

# %% [markdown]
# * sns.joinplot

# %%
sns.jointplot(x='Petal.Length', y='Petal.Width', data=iris)
plt.show()

# %% [markdown]
# * 그래프로 부터 파악된 내용을 적어 봅시다.

# %%
#대체적으로 길이와 넓이에 따라 상관관계가 있다.

# %% [markdown]
# ② boston의 indus(비소매상업지구의 면적비율)와 medv(집값)의 관계를 살펴보기 위해 산점도를 그려봅시다.
# * plt.scatter

# %%
plt.scatter('indus', 'medv', data=boston)
plt.show()

# %% [markdown]
# * sns.scatterplot

# %%
sns.scatterplot(x='indus', y='medv', data=boston)
plt.show()

# %% [markdown]
# * sns.jointplot

# %%
sns.jointplot(x='indus',y='medv', data=boston)
plt.show()

# %% [markdown]
# * 그래프로 부터 파악된 내용을 적어 봅시다.

# %%
# indus(비소매상업지구의 면적비율)와 medv(집값) 상관관계가 없어보인다.

# %% [markdown]
# ③ air의 Temp와 Ozone의 관계를 살펴보기 위해 산점도를 그려봅시다.
# * plt.scatter

# %%
plt.scatter(data=air, x='Temp', y='Ozone')
plt.show()

# %% [markdown]
# * sns.scatterplot

# %%
sns.scatterplot('Temp','Ozone',data=air)
plt.show()

# %% [markdown]
# * sns.jointplot

# %%
sns.jointplot(x='Temp', y='Ozone', data=air)
plt.show()

# %% [markdown]
# * 그래프로 부터 파악된 내용을 적어 봅시다.

# %% [markdown]
# * Temp와 Ozone이 관련이 있어 보인다.

# %% [markdown]
# ### 2) 한꺼번에 산점도 그리기 : sns.pairplot

# %%
air.head()
# Out:
#    Ozone  Solar.R  Wind  Temp       Date  Month  Weekday
# 0     41    190.0   7.4    67 1973-05-01      5        1
# 1     36    118.0   8.0    72 1973-05-02      5        2
# 2     12    149.0  12.6    74 1973-05-03      5        3
# 3     18    313.0  11.5    62 1973-05-04      5        4
# 4     19      NaN  14.3    56 1973-05-05      5        5

# %% [markdown]
# ① air 데이터프레임에서 Month와 Day를 제외하고 산점도를 한꺼번에 그려봅시다.

# %%
sns.pairplot(air.loc[:,['Ozone','Solar.R','Wind','Temp','Date']])
plt.show()

# %%
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ② iris 데이터프레임에 대해서, Species를 제외하고 한꺼번에 산점도를 그려봅시다.

# %%
sns.pairplot(iris.loc[:,['Sepal.Length','Sepal.Width','Petal.Length','Petal.Width']])
plt.show()

# %% [markdown]
# ## 3.수치화 : 상관분석

# %%
import scipy.stats as spst

# %% [markdown]
# ① boston.indus와 boston.medv의 관계를 수치화 해 봅시다.
#
# 결과를 해석해 봅시다.

# %%
spst.pearsonr(boston['indus'], boston['medv'])
# Out:
# (-0.4837251600283729, 4.900259981751351e-31)

# %%
boston.corr()
# Out:
#              crim     indus      chas       nox        rm       age       dis  \
# crim     1.000000  0.404916 -0.057487  0.416175 -0.206349  0.354681 -0.379553
# indus    0.404916  1.000000  0.062938  0.763651 -0.391676  0.644779 -0.708027
# chas    -0.057487  0.062938  1.000000  0.091203  0.091251  0.086518 -0.099176
# nox      0.416175  0.763651  0.091203  1.000000 -0.302188  0.731470 -0.769230
# rm      -0.206349 -0.391676  0.091251 -0.302188  1.000000 -0.240265  0.205246
# age      0.354681  0.644779  0.086518  0.731470 -0.240265  1.000000 -0.747881
# dis     -0.379553 -0.708027 -0.099176 -0.769230  0.205246 -0.747881  1.000000
# rad      0.621397  0.595129 -0.007368  0.611441 -0.209847  0.456022 -0.494588
# tax      0.578307  0.720760 -0.035587  0.668023 -0.292048  0.506456 -0.534432
# ptratio  0.289564  0.383248 -0.121515  0.188933 -0.355501  0.261515 -0.232471
# black   -0.388967 -0.356977  0.048788 -0.380051  0.128069 -0.273534  0.291512
# lstat    0.448531  0.603800 -0.053929  0.590879 -0.613808  0.602339 -0.496996
# medv    -0.382994 -0.483725  0.175260 -0.427321  0.695360 -0.376955  0.249929
# zn2     -0.226359 -0.581680 -0.057650 -0.543283  0.323471 -0.577690  0.705671
#
#               rad       tax   ptratio     black     lstat      medv       zn2
# crim     0.621397  0.578307  0.289564 -0.388967  0.448531 -0.382994 -0.226359
# indus    0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725 -0.581680
# chas    -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260 -0.057650
# nox      0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321 -0.543283
# rm      -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360  0.323471
# age      0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955 -0.577690
# dis     -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929  0.705671
# rad      1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626 -0.349441
# tax      0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536 -0.372593
# ptratio  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787 -0.444260
# black   -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461  0.201134
# lstat    0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663 -0.425383
# medv    -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000  0.364659
# zn2     -0.349441 -0.372593 -0.444260  0.201134 -0.425383  0.364659  1.000000

# %% [markdown]
# ② carseat의 각 변수들 간에 상관 계수를 구해 봅시다.

# %%
carseat.corr()
# Out:
#                 Sales  CompPrice    Income  Advertising  Population     Price  \
# Sales        1.000000   0.064079  0.151951     0.269507    0.050471 -0.444951
# CompPrice    0.064079   1.000000 -0.080653    -0.024199   -0.094707  0.584848
# Income       0.151951  -0.080653  1.000000     0.058995   -0.007877 -0.056698
# Advertising  0.269507  -0.024199  0.058995     1.000000    0.265652  0.044537
# Population   0.050471  -0.094707 -0.007877     0.265652    1.000000 -0.012144
# Price       -0.444951   0.584848 -0.056698     0.044537   -0.012144  1.000000
# Age         -0.231815  -0.100239 -0.004670    -0.004557   -0.042663 -0.102177
#
#                   Age
# Sales       -0.231815
# CompPrice   -0.100239
# Income      -0.004670
# Advertising -0.004557
# Population  -0.042663
# Price       -0.102177
# Age          1.000000

# %% [markdown]
# * 위 결과를 sns.heatmap()으로 그려 봅시다.

# %%
plt.figure(figsize=(17,7))
sns.heatmap(carseat.corr(), annot=True)
plt.show()

# %% [markdown]
# ③ 위 결과에서 가장 강한 상관관계와 약한 상관관계를 찾아 봅시다.

# %%
# 강한 상관관계 : ComPrice와 Price
# 약한 상관관계 : Age와 Advertising
